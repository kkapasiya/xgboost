# %%
import pandas as pd
data=pd.read_csv('pima-indians-diabetes.csv')
data.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                           148
# 1                         1                            85
# 2                         8                           183
# 3                         1                            89
# 4                         0                           137
#
#    Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# 0                                72                               35
# 1                                66                               29
# 2                                64                                0
# 3                                66                               23
# 4                                40                               35
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                               0
# 1                               0
# 2                               0
# 3                              94
# 4                             168
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age  Is Diabetic
# 0   50            1
# 1   31            0
# 2   32            1
# 3   21            0
# 4   33            1

# %%
data.describe()
# Out:
#        Number of times pregnant  Plasma glucose concentration  \
# count                768.000000                    768.000000
# mean                   3.845052                    120.894531
# std                    3.369578                     31.972618
# min                    0.000000                      0.000000
# 25%                    1.000000                     99.000000
# 50%                    3.000000                    117.000000
# 75%                    6.000000                    140.250000
# max                   17.000000                    199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# count                        768.000000                       768.000000
# mean                          69.105469                        20.536458
# std                           19.355807                        15.952218
# min                            0.000000                         0.000000
# 25%                           62.000000                         0.000000
# 50%                           72.000000                        23.000000
# 75%                           80.000000                        32.000000
# max                          122.000000                        99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      768.000000
# mean                        79.799479
# std                        115.244002
# min                          0.000000
# 25%                          0.000000
# 50%                         30.500000
# 75%                        127.250000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      768.000000
# mean                                        31.992578
# std                                          7.884160
# min                                          0.000000
# 25%                                         27.300000
# 50%                                         32.000000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function         Age  Is Diabetic
# count                  768.000000  768.000000   768.000000
# mean                     0.471876   33.240885     0.348958
# std                      0.331329   11.760232     0.476951
# min                      0.078000   21.000000     0.000000
# 25%                      0.243750   24.000000     0.000000
# 50%                      0.372500   29.000000     0.000000
# 75%                      0.626250   41.000000     1.000000
# max                      2.420000   81.000000     1.000000

# %%
col=['Plasma glucose concentration','Diastolic blood pressure (mm Hg)','Triceps skinfold thickness (mm)',
    '2-Hour serum insulin (mu U/ml)','Body mass index (weight in kg/(height in m)^2)','Diabetes pedigree function',
    'Age']

# %%
import numpy as np
for cols in col:
    data[cols]=data[cols].replace(0,np.nan)

# %%
data.describe()
# Out:
#        Number of times pregnant  Plasma glucose concentration  \
# count                768.000000                    763.000000
# mean                   3.845052                    121.686763
# std                    3.369578                     30.535641
# min                    0.000000                     44.000000
# 25%                    1.000000                     99.000000
# 50%                    3.000000                    117.000000
# 75%                    6.000000                    141.000000
# max                   17.000000                    199.000000
#
#        Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# count                        733.000000                       541.000000
# mean                          72.405184                        29.153420
# std                           12.382158                        10.476982
# min                           24.000000                         7.000000
# 25%                           64.000000                        22.000000
# 50%                           72.000000                        29.000000
# 75%                           80.000000                        36.000000
# max                          122.000000                        99.000000
#
#        2-Hour serum insulin (mu U/ml)  \
# count                      394.000000
# mean                       155.548223
# std                        118.775855
# min                         14.000000
# 25%                         76.250000
# 50%                        125.000000
# 75%                        190.000000
# max                        846.000000
#
#        Body mass index (weight in kg/(height in m)^2)  \
# count                                      757.000000
# mean                                        32.457464
# std                                          6.924988
# min                                         18.200000
# 25%                                         27.500000
# 50%                                         32.300000
# 75%                                         36.600000
# max                                         67.100000
#
#        Diabetes pedigree function         Age  Is Diabetic
# count                  768.000000  768.000000   768.000000
# mean                     0.471876   33.240885     0.348958
# std                      0.331329   11.760232     0.476951
# min                      0.078000   21.000000     0.000000
# 25%                      0.243750   24.000000     0.000000
# 50%                      0.372500   29.000000     0.000000
# 75%                      0.626250   41.000000     1.000000
# max                      2.420000   81.000000     1.000000

# %%
data.isnull().sum()
# Out:
# Number of times pregnant                            0
# Plasma glucose concentration                        5
# Diastolic blood pressure (mm Hg)                   35
# Triceps skinfold thickness (mm)                   227
# 2-Hour serum insulin (mu U/ml)                    374
# Body mass index (weight in kg/(height in m)^2)     11
# Diabetes pedigree function                          0
# Age                                                 0
# Is Diabetic                                         0
# dtype: int64

# %%
data['Plasma glucose concentration']=data['Plasma glucose concentration'].fillna(data['Plasma glucose concentration'].mode()[0])
data['Diastolic blood pressure (mm Hg)']=data['Diastolic blood pressure (mm Hg)'].fillna(data['Diastolic blood pressure (mm Hg)'].mode()[0])
data['Triceps skinfold thickness (mm)']=data['Triceps skinfold thickness (mm)'].fillna(data['Triceps skinfold thickness (mm)'].mean())
data['2-Hour serum insulin (mu U/ml)']=data['2-Hour serum insulin (mu U/ml)'].fillna(data['2-Hour serum insulin (mu U/ml)'].mean())
data['Body mass index (weight in kg/(height in m)^2)']=data['Body mass index (weight in kg/(height in m)^2)'].fillna(data['Body mass index (weight in kg/(height in m)^2)'].mean())

# %%
data.isnull().sum()
# Out:
# Number of times pregnant                          0
# Plasma glucose concentration                      0
# Diastolic blood pressure (mm Hg)                  0
# Triceps skinfold thickness (mm)                   0
# 2-Hour serum insulin (mu U/ml)                    0
# Body mass index (weight in kg/(height in m)^2)    0
# Diabetes pedigree function                        0
# Age                                               0
# Is Diabetic                                       0
# dtype: int64

# %%
x=data.drop('Is Diabetic',axis=1)

# %%
#create distribution plot for each column.
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.figure(figsize=(20,25))   #to decide each figure size
plotnumber=1
for column in data:
    if plotnumber <=9:
        ax=plt.subplot(4,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column)
    plotnumber+=1
plt.tight_layout()  #manage the spacing between plots

# %% [markdown]
# The data distribution looks decent enough and there doesn't seem to be any skewness.

# %%
y=data['Is Diabetic']

# %%
x.head()
# Out:
#    Number of times pregnant  Plasma glucose concentration  \
# 0                         6                         148.0
# 1                         1                          85.0
# 2                         8                         183.0
# 3                         1                          89.0
# 4                         0                         137.0
#
#    Diastolic blood pressure (mm Hg)  Triceps skinfold thickness (mm)  \
# 0                              72.0                         35.00000
# 1                              66.0                         29.00000
# 2                              64.0                         29.15342
# 3                              66.0                         23.00000
# 4                              40.0                         35.00000
#
#    2-Hour serum insulin (mu U/ml)  \
# 0                      155.548223
# 1                      155.548223
# 2                      155.548223
# 3                       94.000000
# 4                      168.000000
#
#    Body mass index (weight in kg/(height in m)^2)  Diabetes pedigree function  \
# 0                                            33.6                       0.627
# 1                                            26.6                       0.351
# 2                                            23.3                       0.672
# 3                                            28.1                       0.167
# 4                                            43.1                       2.288
#
#    Age
# 0   50
# 1   31
# 2   32
# 3   21
# 4   33

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_scaled=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
# fit model no training data
import xgboost as xgb
from sklearn import datasets
from xgboost import XGBClassifier

# %%
model = XGBClassifier(objective='binary:logistic')
model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_train)
accuracy=accuracy_score(y_train,y_pred)
accuracy
# Out:
# 0.8901303538175046

# %%
y_test_pred=model.predict(x_test)
accuracy=accuracy_score(y_test,y_test_pred)
accuracy
# Out:
# 0.7792207792207793

# %%
# Now to increae the accuracy of the model, we'll do hyperparameter tuning using grid search
from sklearn.model_selection import GridSearchCV
param_grid={
   
    ' learning_rate':[1,0.5,0.1,0.01,0.001],
    'max_depth': [3,5,10,20],
    'n_estimators':[10,50,100,200]
    
}
grid= GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid, verbose=3)
grid.fit(x_train,y_train)
# Out:
# C:\Users\kapasiya\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=0.721, total=   0.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=0.765, total=   0.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=10, score=0.760, total=   0.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.726, total=   0.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=3, n_estimators=50, score=0.765, total=   0.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.721, total=   0.1s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.754, total=   0.1s
# [CV]  learning_rate=1, max_depth=3, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=100, score=0.765, total=   0.1s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.726, total=   0.1s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=1, max_depth=3, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=0.732, total=   0.0s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=1, max_depth=5, n_estimators=10 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=10, score=0.754, total=   0.0s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.737, total=   0.0s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=1, max_depth=5, n_estimators=50 ..................
# [CV]   learning_rate=1, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.743, total=   0.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=100 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.737, total=   0.2s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.721, total=   0.1s
# [CV]  learning_rate=1, max_depth=5, n_estimators=200 .................
# [CV]   learning_rate=1, max_depth=5, n_estimators=200, score=0.743, total=   0.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=1, max_depth=10, n_estimators=10 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.749, total=   0.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=50 .................
# [CV]   learning_rate=1, max_depth=10, n_estimators=50, score=0.732, total=   0.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.737, total=   0.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=100 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=100, score=0.715, total=   0.1s
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=1, max_depth=10, n_estimators=200 ................
# [CV]   learning_rate=1, max_depth=10, n_estimators=200, score=0.721, total=   0.2s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=1, max_depth=20, n_estimators=10 .................
# [CV]   learning_rate=1, max_depth=20, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.760, total=   0.1s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=1, max_depth=20, n_estimators=50 .................
# [CV]   learning_rate=1, max_depth=20, n_estimators=50, score=0.743, total=   0.1s
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.749, total=   0.1s
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=1, max_depth=20, n_estimators=100 ................
# [CV]   learning_rate=1, max_depth=20, n_estimators=100, score=0.721, total=   0.1s
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.737, total=   0.2s
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.732, total=   0.2s
# [CV]  learning_rate=1, max_depth=20, n_estimators=200 ................
# [CV]   learning_rate=1, max_depth=20, n_estimators=200, score=0.704, total=   0.2s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=0.721, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=0.765, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=10 ................
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=10, score=0.760, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.726, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=50 ................
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=50, score=0.765, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.721, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.754, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=100 ...............
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=100, score=0.765, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.726, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=3, n_estimators=200 ...............
# [CV]   learning_rate=0.5, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=0.732, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=10 ................
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=10, score=0.754, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=50 ................
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.743, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=100 ...............
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.721, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=5, n_estimators=200 ...............
# [CV]   learning_rate=0.5, max_depth=5, n_estimators=200, score=0.743, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=10 ...............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.749, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=50 ...............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=50, score=0.732, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.737, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=100 ..............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=100, score=0.715, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=0.5, max_depth=10, n_estimators=200 ..............
# [CV]   learning_rate=0.5, max_depth=10, n_estimators=200, score=0.721, total=   0.2s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=10 ...............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50 ...............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=50, score=0.760, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50 ...............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=50 ...............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=50, score=0.743, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100 ..............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=100, score=0.749, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100 ..............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=100 ..............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=100, score=0.721, total=   0.1s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200 ..............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=200, score=0.737, total=   0.2s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200 ..............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=200, score=0.732, total=   0.2s
# [CV]  learning_rate=0.5, max_depth=20, n_estimators=200 ..............
# [CV]   learning_rate=0.5, max_depth=20, n_estimators=200, score=0.704, total=   0.2s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10 ................
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=10, score=0.721, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10 ................
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=10, score=0.765, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=10 ................
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=10, score=0.760, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50 ................
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=50, score=0.726, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50 ................
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=50 ................
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=50, score=0.765, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100 ...............
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=100, score=0.721, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100 ...............
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=100, score=0.754, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=100 ...............
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=100, score=0.765, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200 ...............
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=200, score=0.726, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200 ...............
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=200 ...............
# [CV]   learning_rate=0.1, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=10 ................
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=10, score=0.732, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=10 ................
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=10 ................
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=10, score=0.754, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=50 ................
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=50, score=0.737, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=50 ................
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=50 ................
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=100 ...............
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=100, score=0.743, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=100 ...............
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=100 ...............
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=200 ...............
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=200 ...............
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=200, score=0.721, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=200 ...............
# [CV]   learning_rate=0.1, max_depth=5, n_estimators=200, score=0.743, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=10 ...............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=10 ...............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=10 ...............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=50 ...............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=50, score=0.749, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=50 ...............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=50 ...............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=50, score=0.732, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=100 ..............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=100, score=0.737, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=100 ..............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=100 ..............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=100, score=0.715, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=200 ..............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=200 ..............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=0.1, max_depth=10, n_estimators=200 ..............
# [CV]   learning_rate=0.1, max_depth=10, n_estimators=200, score=0.721, total=   0.2s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=10 ...............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=10 ...............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=10 ...............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=50 ...............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=50, score=0.760, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=50 ...............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=50 ...............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=50, score=0.743, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=100 ..............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=100, score=0.749, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=100 ..............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=100 ..............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=100, score=0.721, total=   0.1s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=200 ..............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=200, score=0.737, total=   0.2s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=200 ..............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=200, score=0.732, total=   0.2s
# [CV]  learning_rate=0.1, max_depth=20, n_estimators=200 ..............
# [CV]   learning_rate=0.1, max_depth=20, n_estimators=200, score=0.704, total=   0.2s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=10 ...............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=10, score=0.721, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=10 ...............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=10, score=0.765, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=10 ...............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=10, score=0.760, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50 ...............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=50, score=0.726, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50 ...............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=50 ...............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=50, score=0.765, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100 ..............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=100, score=0.721, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100 ..............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=100, score=0.754, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=100 ..............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=100, score=0.765, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=200 ..............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=200, score=0.726, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=200 ..............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=3, n_estimators=200 ..............
# [CV]   learning_rate=0.01, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=10 ...............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=10, score=0.732, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=10 ...............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=10 ...............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=10, score=0.754, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50 ...............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=50, score=0.737, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50 ...............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=50 ...............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100 ..............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=100, score=0.743, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100 ..............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=100 ..............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200 ..............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200 ..............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=200, score=0.721, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=5, n_estimators=200 ..............
# [CV]   learning_rate=0.01, max_depth=5, n_estimators=200, score=0.743, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=10 ..............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=10 ..............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=10 ..............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=50 ..............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=50, score=0.749, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=50 ..............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=50 ..............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=50, score=0.732, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=100 .............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=100, score=0.737, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=100 .............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=100 .............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=100, score=0.715, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=200 .............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=200 .............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=0.01, max_depth=10, n_estimators=200 .............
# [CV]   learning_rate=0.01, max_depth=10, n_estimators=200, score=0.721, total=   0.2s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=10 ..............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=10 ..............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=10 ..............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=50 ..............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=50, score=0.760, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=50 ..............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=50 ..............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=50, score=0.743, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=100 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=100, score=0.749, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=100 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=100 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=100, score=0.721, total=   0.1s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=200 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=200, score=0.737, total=   0.2s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=200 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=200, score=0.732, total=   0.2s
# [CV]  learning_rate=0.01, max_depth=20, n_estimators=200 .............
# [CV]   learning_rate=0.01, max_depth=20, n_estimators=200, score=0.704, total=   0.2s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=10, score=0.721, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=10, score=0.765, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=10, score=0.760, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=50, score=0.726, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=50, score=0.765, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=100, score=0.721, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=100, score=0.754, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=100, score=0.765, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=200, score=0.726, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=3, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=3, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=10, score=0.732, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=10 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=10, score=0.754, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=50, score=0.737, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=50 ..............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=50, score=0.754, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=100, score=0.743, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=100 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=200, score=0.737, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=200, score=0.721, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=5, n_estimators=200 .............
# [CV]   learning_rate=0.001, max_depth=5, n_estimators=200, score=0.743, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=10, score=0.749, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=50, score=0.749, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=50, score=0.732, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=100, score=0.737, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=100, score=0.726, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=100, score=0.715, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=200, score=0.726, total=   0.2s
# [CV]  learning_rate=0.001, max_depth=10, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=10, n_estimators=200, score=0.721, total=   0.2s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=10, score=0.743, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=10 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=10, score=0.715, total=   0.0s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=50, score=0.760, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=50, score=0.737, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=50 .............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=50, score=0.743, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=100, score=0.749, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=100, score=0.732, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=100 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=100, score=0.721, total=   0.1s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=200, score=0.737, total=   0.2s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=200, score=0.732, total=   0.2s
# [CV]  learning_rate=0.001, max_depth=20, n_estimators=200 ............
# [CV]   learning_rate=0.001, max_depth=20, n_estimators=200, score=0.704, total=   0.2s
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed:   17.1s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                      colsample_bylevel=1, colsample_bynode=1,
#                                      colsample_bytree=1, gamma=0,
#                                      learning_rate=0.1, max_delta_step=0,
#                                      max_depth=3, min_child_weight=1,
#                                      missing=None, n_estimators=100, n_jobs=1,
#                                      nthread=None, objective='binary:logistic',
#                                      random_state=0, reg_alpha=0, reg_lambda=1,
#                                      scale_pos_weight=1, seed=None, silent=None,
#                                      subsample=1, verbosity=1),
#              iid='warn', n_jobs=None,
#              param_grid={' learning_rate': [1, 0.5, 0.1, 0.01, 0.001],
#                          'max_depth': [3, 5, 10, 20],
#                          'n_estimators': [10, 50, 100, 200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# To  find the parameters givingmaximum accuracy
grid.best_params_
# Out:
# {' learning_rate': 1, 'max_depth': 3, 'n_estimators': 10}

# %%
# Create new model using the same parameters
new_model=XGBClassifier(learning_rate= 1, max_depth= 3, n_estimators= 10)
new_model.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=1,
#               max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#               n_estimators=10, n_jobs=1, nthread=None,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#               subsample=1, verbosity=1)

# %%
y_pred_new = new_model.predict(x_test)
accuracy_new = accuracy_score(y_test,y_pred_new)
accuracy_new
# Out:
# 0.7489177489177489
